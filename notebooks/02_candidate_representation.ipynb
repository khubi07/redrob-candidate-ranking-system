# %%
import json
import sys

sys.path.append("../src")

from candidate_representation import build_candidate 

from candidate_representation import create_retrieval_document

# %%
with open("../data/sample_candidates.json", "r", encoding="utf-8") as f:
    candidates = json.load(f)

print("Total candidates:", len(candidates))
# Out:
# Total candidates: 50

# %%
sample_candidate = candidates[0]

print(sample_candidate["candidate_id"])
# Out:
# CAND_0000001

# %%
print(type(sample_candidate["skills"]))
print(sample_candidate["skills"][:3])
# Out:
# <class 'list'>
# [{'name': 'Tailwind', 'proficiency': 'intermediate', 'endorsements': 3, 'duration_months': 13}, {'name': 'NLP', 'proficiency': 'advanced', 'endorsements': 37, 'duration_months': 26}, {'name': 'Image Classification', 'proficiency': 'advanced', 'endorsements': 7, 'duration_months': 40}]

# %%
print(sample_candidate["education"][0])
# Out:
# {'institution': 'Lovely Professional University', 'degree': 'B.E.', 'field_of_study': 'Computer Science', 'start_year': 2017, 'end_year': 2020, 'grade': '8.24 CGPA', 'tier': 'tier_3'}

# %%
print(sample_candidate["career_history"][0])
# Out:
# {'company': 'Mindtree', 'title': 'Backend Engineer', 'start_date': '2024-03-08', 'end_date': None, 'duration_months': 27, 'is_current': True, 'industry': 'IT Services', 'company_size': '10001+', 'description': 'Implemented streaming data pipelines on Kafka and Spark Streaming for a real-time user-activity processing platform. Designed the schema-registry integration, the watermark/state management approach, and the deduplication logic for late-arriving events. Worked closely with the data science team to make sure feature pipelines aligned with what their models needed. Most of my career has been data engineering, with some adjacent ML exposure.'}

# %%
print(sample_candidate["profile"])
# Out:
# {'anonymized_name': 'Ira Vora', 'headline': 'Backend Engineer | SQL, Spark, Cloud', 'summary': "Software / data professional with 6.9 years of experience building data pipelines, backend systems, and analytics infrastructure. I'm a backend/data hybrid — Spark, Airflow, SQL warehouses are home territory; I'm building competence on the ML side. My toolkit is solid on the data engineering side — Python, SQL, Spark, Airflow, warehouse design — and I've completed a couple of self-directed ML projects (Kaggle competitions, side projects fine-tuning small models). Interested in transitioning toward more AI/ML-focused work, ideally at a company where I can leverage my existing data-infra skills while learning modern ML practice.", 'location': 'Toronto', 'country': 'Canada', 'years_of_experience': 6.9, 'current_title': 'Backend Engineer', 'current_company': 'Mindtree', 'current_company_size': '10001+', 'current_industry': 'IT Services'}

# %%
print(sample_candidate["certifications"][:3])
# Out:
# []

# %%
print(sample_candidate["languages"])
# Out:
# [{'language': 'English', 'proficiency': 'professional'}, {'language': 'Hindi', 'proficiency': 'conversational'}]

# %%
create_retrieval_document(sample_candidate)
# Out:
# 'Headline: Backend Engineer | SQL, Spark, Cloud\nSkills: Tailwind, NLP, Image Classification, Fine-tuning LLMs, Weights & Biases, Speech Recognition, Photoshop, TTS, LoRA, Apache Beam, AWS, Flask, BentoML, Milvus, GANs, Statistical Modeling, GCP\nEducation: B.E. Computer Science\nExperience Title: Backend Engineer\nExperience Description: Implemented streaming data pipelines on Kafka and Spark Streaming for a real-time user-activity processing platform. Designed the schema-registry integration, the watermark/state management approach, and the deduplication logic for late-arriving events. Worked closely with the data science team to make sure feature pipelines aligned with what their models needed. Most of my career has been data engineering, with some adjacent ML exposure.\nExperience Title: Analytics Engineer\nExperience Description: Built and maintained data pipelines on Apache Airflow processing ~500GB of daily transactional data across 12 source systems. Worked extensively with S
# ...

# %%
candidate = build_candidate(sample_candidate)

print(candidate.skills[0])
print(candidate.experiences[0])
print(candidate.metadata)
# Out:
# Skill(name='Tailwind', proficiency='intermediate', endorsements=3, duration_months=13)
# Experience(company='Mindtree', title='Backend Engineer', duration_months=27, is_current=True, industry='IT Services', company_size='10001+', description='Implemented streaming data pipelines on Kafka and Spark Streaming for a real-time user-activity processing platform. Designed the schema-registry integration, the watermark/state management approach, and the deduplication logic for late-arriving events. Worked closely with the data science team to make sure feature pipelines aligned with what their models needed. Most of my career has been data engineering, with some adjacent ML exposure.')
# {'num_skills': 17, 'num_jobs': 2, 'num_education': 1}
